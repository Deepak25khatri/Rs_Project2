# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/amazon-ml-challenge/__notebook_source__.ipynb
# /kaggle/input/amazon-ml-challenge/dataset/sample_submission.csv
# /kaggle/input/amazon-ml-challenge/dataset/concatenated.csv
# /kaggle/input/amazon-ml-challenge/dataset/train.csv
# /kaggle/input/amazon-ml-challenge/dataset/test.csv

# %%
concate_data = pd.read_csv("/kaggle/input/amazon-ml-challenge/dataset/concatenated.csv")

# %%
concate_data.head()
# Out:
#    Unnamed: 0  PRODUCT_ID                                              TITLE  \
# 0           0     1925202  ArtzFolio Tulip Flowers Blackout Curtain for D...
# 1           1     2673191  Marks & Spencer Girls' Pyjama Sets T86_2561C_N...
# 2           2     2765088  PRIKNIK Horn Red Electric Air Horn Compressor ...
# 3           3     1594019  ALISHAH Women's Cotton Ankle Length Leggings C...
# 4           4      283658  The United Empire Loyalists: A Chronicle of th...
#
#                                        BULLET_POINTS  \
# 0  [LUXURIOUS & APPEALING: Beautiful custom-made ...
# 1  [Harry Potter Hedwig Pyjamas (6-16 Yrs),100% c...
# 2  [Loud Dual Tone Trumpet Horn, Compatible With ...
# 3  [Made By 95%cotton and 5% Lycra which gives yo...
# 4                                                NaN
#
#                                          DESCRIPTION  PRODUCT_TYPE_ID  \
# 0                                                NaN             1650
# 1                                                NaN             2755
# 2  Specifications: Color: Red, Material: Aluminiu...             7537
# 3  AISHAH Women's Lycra Cotton Ankel Leggings. Br...             2996
# 4                                                NaN             6112
#
#    PRODUCT_LENGTH                                BULLET_POINTS_JOINT  \
# 0     2125.980000  LUXURIOUS & APPEALING: Beautiful custom-made c...
# 1      393.700000  Harry Potter Hedwig Pyjamas (6-16 Yrs),100% co...
# 2      748.031495  Loud Dual Tone Trumpet Horn Compatible With SX...
# 3      787.401574  Made By 95%cotton and 5% Lycra which gives you...
# 4      598.424000                                                NaN
#
#                                          CONCAT_DATA
# 0  LUXURIOUS & APPEALING: Beautiful custom-made c...
# 1  Harry Potter Hedwig Pyjamas (6-16 Yrs),100% co...
# 2  Loud Dual Tone Trumpet Horn Compatible With SX...
# 3  Made By 95%cotton and 5% Lycra which gives you...
# 4                                                NaN

# %%
concate_data.shape
# Out:
# (2249688, 9)

# %%
concate_data.isnull().sum()
# Out:
# Unnamed: 0                   0
# PRODUCT_ID                   0
# TITLE                        3
# BULLET_POINTS           837356
# DESCRIPTION            1157372
# PRODUCT_TYPE_ID              0
# PRODUCT_LENGTH               0
# BULLET_POINTS_JOINT     837356
# CONCAT_DATA             783498
# dtype: int64

# %%
concate_data.duplicated().sum()
# Out:
# 0

# %%
x=concate_data.groupby('PRODUCT_TYPE_ID').count()["PRODUCT_ID"]>50
product_type_as_user=x[x].index

# %%
filtered_product_type =concate_data[concate_data['PRODUCT_TYPE_ID'].isin(product_type_as_user)]

# %%
y =filtered_product_type.groupby('TITLE').count()['BULLET_POINTS_JOINT']>=5
multi_type=y[y].index

# %%
filtered_title_type=concate_data[concate_data['TITLE'].isin(multi_type)]

# %%
filtered_title_type
# Out:
#          Unnamed: 0  PRODUCT_ID  \
# 171             171     2155174
# 590             590     1893492
# 592             592     1763196
# 816             816     2188447
# 1438           1438     2019640
# ...             ...         ...
# 2247571     2247581     1818310
# 2247640     2247650     1628130
# 2248548     2248558     2755948
# 2248978     2248988     1414679
# 2249143     2249153     2007751
#
#                                                      TITLE  \
# 171                       Printed Back Cover for Lenovo A7
# 590      BLISSart Coffee Mug, Chai Cup, Milk Mugs, Tea ...
# 592             NyeKoncept Mid-Century Dining Chair, Green
# 816      shoe craft women and girls casual wedges slipp...
# 1438     Unaxo Back Cover for Tecno Camon 16, Back Case...
# ...                                                    ...
# 2247571  Amagav® Printed Stylish Silicone Soft Matte Fi...
# 2247640  Men's Cycling Jersey and Shorts Set Short Slee...
# 2248548  Baggy Cotton Linen Pants for Women Casual Elas...
# 2248978  Port Authority Ladies Long Sleeve Carefree Pop...
# 2249143  Happy Bunny 100% Pure Cotton Womens Full Slip ...
#
#                                              BULLET_POINTS  \
# 171      [Slim Fitting One-Piece Clip-On-Case,Silicon C...
# 590      [Print Quality- We Use 6 Ink Printer to Print ...
# 592      [CAFR approved,Dye-sublimation printed design,...
# 816                  [wedges sandal,Comfortable,Dailywear]
# 1438                [Silicon,Back Cover,Printed,Back Case]
# ...                                                    ...
# 2247571  [Color Might Slightly Vary due to Screen Perfo...
# 2247640  [❤【NOTE】:Our size is not standard size in US, ...
# 2248548  [➤【Breathable & Comfort Material】Women's Baggy...
# 2248978  [4.3-ounce, 100% ring spun combed cotton,50/50...
# 2249143  [Fabric: 100% Pure Cotton as expected with int...
#
#                                                DESCRIPTION  PRODUCT_TYPE_ID  \
# 171      Designer Back Case For Lenovo A7, provides pro...            12064
# 590      <p><strong>About BISSart (Child Brand Of LEE-J...             1396
# 592                                                    NaN             8345
# 816      shoe craft Sandals for Women Stylish Flat Casu...             3301
# 1438     Unaxo cases are made to bring fun back into de...            12064
# ...                                                    ...              ...
# 2247571  Get Best Printed Cover for your phone, These M...            12064
# 2247640  <br>Description: <br>Material: Polyester <br>S...             2854
# 2248548  <b>Baggy Cotton Linen Pants for Women Casual E...             3081
# 2248978  With its easygoing fit and scoop neck, this te...             2985
# 2249143  Exclusive Happy Bunny 100% Pure Cotton Non-Str...             3011
#
#          PRODUCT_LENGTH                                BULLET_POINTS_JOINT  \
# 171          393.700787  Slim Fitting One-Piece Clip-On-Case,Silicon Ca...
# 590          472.440944  Print Quality- We Use 6 Ink Printer to Print M...
# 592         2150.000000  CAFR approved,Dye-sublimation printed design,M...
# 816         1574.803148                wedges sandal,Comfortable,Dailywear
# 1438         944.881889               Silicon,Back Cover,Printed,Back Case
# ...                 ...                                                ...
# 2247571      393.700787  Color Might Slightly Vary due to Screen Perfor...
# 2247640      393.700787  ❤【NOTE】:Our size is not standard size in US pl...
# 2248548      590.551180  ➤【Breathable & Comfort Material】Women's Baggy ...
# 2248978      500.000000  4.3-ounce 100% ring spun combed cotton,50/50 r...
# 2249143      551.181102  Fabric: 100% Pure Cotton as expected with inte...
#
#                                                CONCAT_DATA
# 171      Slim Fitting One-Piece Clip-On-Case,Silicon Ca...
# 590      Print Quality- We Use 6 Ink Printer to Print M...
# 592      CAFR approved,Dye-sublimation printed design,M...
# 816      wedges sandal,Comfortable,Dailywearshoe craft ...
# 1438     Silicon,Back Cover,Printed,Back CaseUnaxo case...
# ...                                                    ...
# 2247571  Color Might Slightly Vary due to Screen Perfor...
# 2247640  ❤【NOTE】:Our size is not standard size in US pl...
# 2248548  ➤【Breathable & Comfort Material】Women's Baggy ...
# 2248978  4.3-ounce 100% ring spun combed cotton,50/50 r...
# 2249143  Fabric: 100% Pure Cotton as expected with inte...
#
# [6406 rows x 9 columns]

# %%
pt_item_based=filtered_title_type.pivot_table(index='TITLE',columns='PRODUCT_TYPE_ID',values='PRODUCT_LENGTH')

# %%
pt_item_based
# Out:
# PRODUCT_TYPE_ID                                     0      2      6      \
# TITLE
# "Laptop Backpack|| Laptop Bag||College Bag||Bac...    NaN    NaN    NaN
# "PH" POSHAKHUB Women Turquoise & Golden Printed...    NaN    NaN    NaN
# 1 Stop Fashion Women's Multi-Coloured Crep Knee...    NaN    NaN    NaN
# 1100 Series Aluminum Door Canopy with Support Arms    NaN    NaN    NaN
# 17Hills® Camisole Tank Top Vest Racerback Sando...    NaN    NaN    NaN
# ...                                                   ...    ...    ...
# naioewe Onesie Pajamas for Women Sexy with Butt...    NaN    NaN    NaN
# shoe craft women and girls casual wedges slippe...    NaN    NaN    NaN
# zia carpets Carved Embossed Carpet for Your Hom...    NaN    NaN    NaN
# zia carpets Handmade Woollen Thick Modern Tufft...    NaN    NaN    NaN
# zia carpets Modern Soft Shaggy Rugs Fluffy Home...    NaN    NaN    NaN
#
# PRODUCT_TYPE_ID                                     227    326    486    \
# TITLE
# "Laptop Backpack|| Laptop Bag||College Bag||Bac...    NaN    NaN    NaN
# "PH" POSHAKHUB Women Turquoise & Golden Printed...    NaN    NaN    NaN
# 1 Stop Fashion Women's Multi-Coloured Crep Knee...    NaN    NaN    NaN
# 1100 Series Aluminum Door Canopy with Support Arms    NaN    NaN    NaN
# 17Hills® Camisole Tank Top Vest Racerback Sando...    NaN    NaN    NaN
# ...                                                   ...    ...    ...
# naioewe Onesie Pajamas for Women Sexy with Butt...    NaN    NaN    NaN
# shoe craft women and girls casual wedges slippe...    NaN    NaN    NaN
# zia carpets Carved Embossed Carpet for Your Hom...    NaN    NaN    NaN
# zia carpets Handmade Woollen Thick Modern Tufft...    NaN    NaN    NaN
# zia carpets Modern Soft Shaggy Rugs Fluffy Home...    NaN    NaN    NaN
#
# PRODUCT_TYPE_ID                                     578    597    599    \
# TITLE
# "Laptop Backpack|| Laptop Bag||College Bag||Bac...    NaN    NaN    NaN
# "PH" POSHAKHUB Women Turquoise & Golden Printed...    NaN    NaN    NaN
# 1 Stop Fashion Women's Multi-Coloured Crep Knee...    NaN    NaN    NaN
# 1100 Series Aluminum Door Canopy with Support Arms    NaN    NaN    NaN
# 17Hills® Camisole Tank Top Vest Racerback Sando...    NaN    NaN    NaN
# ...                                                   ...    ...    ...
# naioewe Onesie Pajamas for Women Sexy with Butt...    NaN    NaN    NaN
# shoe craft women and girls casual wedges slippe...    NaN    NaN    NaN
# zia carpets Carved Embossed Carpet for Your Hom...    NaN    NaN    NaN
# zia carpets Handmade Woollen Thick Modern Tufft...    NaN    NaN    NaN
# zia carpets Modern Soft Shaggy Rugs Fluffy Home...    NaN    NaN    NaN
#
# PRODUCT_TYPE_ID                                     666    ...  12456  12556  \
# TITLE                                                      ...
# "Laptop Backpack|| Laptop Bag||College Bag||Bac...    NaN  ...    NaN    NaN
# "PH" POSHAKHUB Women Turquoise & Golden Printed...    NaN  ...    NaN    NaN
# 1 Stop Fashion Women's Multi-Coloured Crep Knee...    NaN  ...    NaN    NaN
# 1100 Series Aluminum Door Canopy with Support Arms    NaN  ...    NaN    NaN
# 17Hills® Camisole Tank Top Vest Racerback Sando...    NaN  ...    NaN    NaN
# ...                                                   ...  ...    ...    ...
# naioewe Onesie Pajamas for Women Sexy with Butt...    NaN  ...    NaN    NaN
# shoe craft women and girls casual wedges slippe...    NaN  ...    NaN    NaN
# zia carpets Carved Embossed Carpet for Your Hom...    NaN  ...    NaN    NaN
# zia carpets Handmade Woollen Thick Modern Tufft...    NaN  ...    NaN    NaN
# zia carpets Modern Soft Shaggy Rugs Fluffy Home...    NaN  ...    NaN    NaN
#
# PRODUCT_TYPE_ID                                     12558  12621  12680  \
# TITLE
# "Laptop Backpack|| Laptop Bag||College Bag||Bac...    NaN    NaN    NaN
# "PH" POSHAKHUB Women Turquoise & Golden Printed...    NaN    NaN    NaN
# 1 Stop Fashion Women's Multi-Coloured Crep Knee...    NaN    NaN    NaN
# 1100 Series Aluminum Door Canopy with Support Arms    NaN    NaN    NaN
# 17Hills® Camisole Tank Top Vest Racerback Sando...    NaN    NaN    NaN
# ...                                                   ...    ...    ...
# naioewe Onesie Pajamas for Women Sexy with Butt...    NaN    NaN    NaN
# shoe craft women and girls casual wedges slippe...    NaN    NaN    NaN
# zia carpets Carved Embossed Carpet for Your Hom...    NaN    NaN    NaN
# zia carpets Handmade Woollen Thick Modern Tufft...    NaN    NaN    NaN
# zia carpets Modern Soft Shaggy Rugs Fluffy Home...    NaN    NaN    NaN
#
# PRODUCT_TYPE_ID                                     12734  12814  12826  \
# TITLE
# "Laptop Backpack|| Laptop Bag||College Bag||Bac...    NaN    NaN    NaN
# "PH" POSHAKHUB Women Turquoise & Golden Printed...    NaN    NaN    NaN
# 1 Stop Fashion Women's Multi-Coloured Crep Knee...    NaN    NaN    NaN
# 1100 Series Aluminum Door Canopy with Support Arms    NaN    NaN    NaN
# 17Hills® Camisole Tank Top Vest Racerback Sando...    NaN    NaN    NaN
# ...                                                   ...    ...    ...
# naioewe Onesie Pajamas for Women Sexy with Butt...    NaN    NaN    NaN
# shoe craft women and girls casual wedges slippe...    NaN    NaN    NaN
# zia carpets Carved Embossed Carpet for Your Hom...    NaN    NaN    NaN
# zia carpets Handmade Woollen Thick Modern Tufft...    NaN    NaN    NaN
# zia carpets Modern Soft Shaggy Rugs Fluffy Home...    NaN    NaN    NaN
#
# PRODUCT_TYPE_ID                                     12829  13080
# TITLE
# "Laptop Backpack|| Laptop Bag||College Bag||Bac...    NaN    NaN
# "PH" POSHAKHUB Women Turquoise & Golden Printed...    NaN    NaN
# 1 Stop Fashion Women's Multi-Coloured Crep Knee...    NaN    NaN
# 1100 Series Aluminum Door Canopy with Support Arms    NaN    NaN
# 17Hills® Camisole Tank Top Vest Racerback Sando...    NaN    NaN
# ...                                                   ...    ...
# naioewe Onesie Pajamas for Women Sexy with Butt...    NaN    NaN
# shoe craft women and girls casual wedges slippe...    NaN    NaN
# zia carpets Carved Embossed Carpet for Your Hom...    NaN    NaN
# zia carpets Handmade Woollen Thick Modern Tufft...    NaN    NaN
# zia carpets Modern Soft Shaggy Rugs Fluffy Home...    NaN    NaN
#
# [885 rows x 239 columns]

# %%
pt_item_based.fillna(0,inplace=True)

# %%
pt_item_based
# Out:
# PRODUCT_TYPE_ID                                     0      2      6      \
# TITLE
# "Laptop Backpack|| Laptop Bag||College Bag||Bac...    0.0    0.0    0.0
# "PH" POSHAKHUB Women Turquoise & Golden Printed...    0.0    0.0    0.0
# 1 Stop Fashion Women's Multi-Coloured Crep Knee...    0.0    0.0    0.0
# 1100 Series Aluminum Door Canopy with Support Arms    0.0    0.0    0.0
# 17Hills® Camisole Tank Top Vest Racerback Sando...    0.0    0.0    0.0
# ...                                                   ...    ...    ...
# naioewe Onesie Pajamas for Women Sexy with Butt...    0.0    0.0    0.0
# shoe craft women and girls casual wedges slippe...    0.0    0.0    0.0
# zia carpets Carved Embossed Carpet for Your Hom...    0.0    0.0    0.0
# zia carpets Handmade Woollen Thick Modern Tufft...    0.0    0.0    0.0
# zia carpets Modern Soft Shaggy Rugs Fluffy Home...    0.0    0.0    0.0
#
# PRODUCT_TYPE_ID                                     227    326    486    \
# TITLE
# "Laptop Backpack|| Laptop Bag||College Bag||Bac...    0.0    0.0    0.0
# "PH" POSHAKHUB Women Turquoise & Golden Printed...    0.0    0.0    0.0
# 1 Stop Fashion Women's Multi-Coloured Crep Knee...    0.0    0.0    0.0
# 1100 Series Aluminum Door Canopy with Support Arms    0.0    0.0    0.0
# 17Hills® Camisole Tank Top Vest Racerback Sando...    0.0    0.0    0.0
# ...                                                   ...    ...    ...
# naioewe Onesie Pajamas for Women Sexy with Butt...    0.0    0.0    0.0
# shoe craft women and girls casual wedges slippe...    0.0    0.0    0.0
# zia carpets Carved Embossed Carpet for Your Hom...    0.0    0.0    0.0
# zia carpets Handmade Woollen Thick Modern Tufft...    0.0    0.0    0.0
# zia carpets Modern Soft Shaggy Rugs Fluffy Home...    0.0    0.0    0.0
#
# PRODUCT_TYPE_ID                                     578    597    599    \
# TITLE
# "Laptop Backpack|| Laptop Bag||College Bag||Bac...    0.0    0.0    0.0
# "PH" POSHAKHUB Women Turquoise & Golden Printed...    0.0    0.0    0.0
# 1 Stop Fashion Women's Multi-Coloured Crep Knee...    0.0    0.0    0.0
# 1100 Series Aluminum Door Canopy with Support Arms    0.0    0.0    0.0
# 17Hills® Camisole Tank Top Vest Racerback Sando...    0.0    0.0    0.0
# ...                                                   ...    ...    ...
# naioewe Onesie Pajamas for Women Sexy with Butt...    0.0    0.0    0.0
# shoe craft women and girls casual wedges slippe...    0.0    0.0    0.0
# zia carpets Carved Embossed Carpet for Your Hom...    0.0    0.0    0.0
# zia carpets Handmade Woollen Thick Modern Tufft...    0.0    0.0    0.0
# zia carpets Modern Soft Shaggy Rugs Fluffy Home...    0.0    0.0    0.0
#
# PRODUCT_TYPE_ID                                     666    ...  12456  12556  \
# TITLE                                                      ...
# "Laptop Backpack|| Laptop Bag||College Bag||Bac...    0.0  ...    0.0    0.0
# "PH" POSHAKHUB Women Turquoise & Golden Printed...    0.0  ...    0.0    0.0
# 1 Stop Fashion Women's Multi-Coloured Crep Knee...    0.0  ...    0.0    0.0
# 1100 Series Aluminum Door Canopy with Support Arms    0.0  ...    0.0    0.0
# 17Hills® Camisole Tank Top Vest Racerback Sando...    0.0  ...    0.0    0.0
# ...                                                   ...  ...    ...    ...
# naioewe Onesie Pajamas for Women Sexy with Butt...    0.0  ...    0.0    0.0
# shoe craft women and girls casual wedges slippe...    0.0  ...    0.0    0.0
# zia carpets Carved Embossed Carpet for Your Hom...    0.0  ...    0.0    0.0
# zia carpets Handmade Woollen Thick Modern Tufft...    0.0  ...    0.0    0.0
# zia carpets Modern Soft Shaggy Rugs Fluffy Home...    0.0  ...    0.0    0.0
#
# PRODUCT_TYPE_ID                                     12558  12621  12680  \
# TITLE
# "Laptop Backpack|| Laptop Bag||College Bag||Bac...    0.0    0.0    0.0
# "PH" POSHAKHUB Women Turquoise & Golden Printed...    0.0    0.0    0.0
# 1 Stop Fashion Women's Multi-Coloured Crep Knee...    0.0    0.0    0.0
# 1100 Series Aluminum Door Canopy with Support Arms    0.0    0.0    0.0
# 17Hills® Camisole Tank Top Vest Racerback Sando...    0.0    0.0    0.0
# ...                                                   ...    ...    ...
# naioewe Onesie Pajamas for Women Sexy with Butt...    0.0    0.0    0.0
# shoe craft women and girls casual wedges slippe...    0.0    0.0    0.0
# zia carpets Carved Embossed Carpet for Your Hom...    0.0    0.0    0.0
# zia carpets Handmade Woollen Thick Modern Tufft...    0.0    0.0    0.0
# zia carpets Modern Soft Shaggy Rugs Fluffy Home...    0.0    0.0    0.0
#
# PRODUCT_TYPE_ID                                     12734  12814  12826  \
# TITLE
# "Laptop Backpack|| Laptop Bag||College Bag||Bac...    0.0    0.0    0.0
# "PH" POSHAKHUB Women Turquoise & Golden Printed...    0.0    0.0    0.0
# 1 Stop Fashion Women's Multi-Coloured Crep Knee...    0.0    0.0    0.0
# 1100 Series Aluminum Door Canopy with Support Arms    0.0    0.0    0.0
# 17Hills® Camisole Tank Top Vest Racerback Sando...    0.0    0.0    0.0
# ...                                                   ...    ...    ...
# naioewe Onesie Pajamas for Women Sexy with Butt...    0.0    0.0    0.0
# shoe craft women and girls casual wedges slippe...    0.0    0.0    0.0
# zia carpets Carved Embossed Carpet for Your Hom...    0.0    0.0    0.0
# zia carpets Handmade Woollen Thick Modern Tufft...    0.0    0.0    0.0
# zia carpets Modern Soft Shaggy Rugs Fluffy Home...    0.0    0.0    0.0
#
# PRODUCT_TYPE_ID                                     12829  13080
# TITLE
# "Laptop Backpack|| Laptop Bag||College Bag||Bac...    0.0    0.0
# "PH" POSHAKHUB Women Turquoise & Golden Printed...    0.0    0.0
# 1 Stop Fashion Women's Multi-Coloured Crep Knee...    0.0    0.0
# 1100 Series Aluminum Door Canopy with Support Arms    0.0    0.0
# 17Hills® Camisole Tank Top Vest Racerback Sando...    0.0    0.0
# ...                                                   ...    ...
# naioewe Onesie Pajamas for Women Sexy with Butt...    0.0    0.0
# shoe craft women and girls casual wedges slippe...    0.0    0.0
# zia carpets Carved Embossed Carpet for Your Hom...    0.0    0.0
# zia carpets Handmade Woollen Thick Modern Tufft...    0.0    0.0
# zia carpets Modern Soft Shaggy Rugs Fluffy Home...    0.0    0.0
#
# [885 rows x 239 columns]

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity_scores = cosine_similarity(pt_item_based)

# %%
similarity_scores.shape
# Out:
# (885, 885)

# %%
def recommend(title):
    # index fetch
    index = np.where(pt_item_based.index==title)[0][0]
    similar_items = sorted(list(enumerate(similarity_scores[index])),key=lambda x:x[1],reverse=True)[1:5]
    
    data = []
    for i in similar_items:
        print(pt_item_based.index[i[0]])

# %%
recommend('2PCS Summer Clothes Outfit Sets, F_Gotal Baby Toddler Girls Floral Big Bowknot Sundress Print Sleeveless Dress + Hat Set')
# Out:
# Adela Lace Mermaid Vintage Flower Girls Dresses Appliques Capped Sleeves Kids Long Pageant Gown AR075
# Girls Clothes Outfits, Fashion Cute Strawberry Print Bow Sundress+Hat 2PC Clothes Set Toddler Infant Kids Clothes Gifts
# "Laptop Backpack|| Laptop Bag||College Bag||Backpack||Office Bag||Casual Bag||Urban Backpack||Day Backpack||Evening Backpack||School Bag"
# "PH" POSHAKHUB Women Turquoise & Golden Printed Anarkali Kurta

# %%
pt_user_based = filtered_title_type.pivot_table(index='PRODUCT_TYPE_ID', columns='TITLE', values='PRODUCT_LENGTH')

# %%
pt_user_based.fillna(0, inplace=True)

# %%
pt_user_based
# Out:
# TITLE            "Laptop Backpack|| Laptop Bag||College Bag||Backpack||Office Bag||Casual Bag||Urban Backpack||Day Backpack||Evening Backpack||School Bag"  \
# PRODUCT_TYPE_ID
# 0                                                              0.0
# 2                                                              0.0
# 6                                                              0.0
# 227                                                            0.0
# 326                                                            0.0
# ...                                                            ...
# 12734                                                          0.0
# 12814                                                          0.0
# 12826                                                          0.0
# 12829                                                          0.0
# 13080                                                          0.0
#
# TITLE            "PH" POSHAKHUB Women Turquoise & Golden Printed Anarkali Kurta  \
# PRODUCT_TYPE_ID
# 0                                                              0.0
# 2                                                              0.0
# 6                                                              0.0
# 227                                                            0.0
# 326                                                            0.0
# ...                                                            ...
# 12734                                                          0.0
# 12814                                                          0.0
# 12826                                                          0.0
# 12829                                                          0.0
# 13080                                                          0.0
#
# TITLE            1 Stop Fashion Women's Multi-Coloured Crep Knee Long W Style Kurtas/Kurti (Pack of 2)  \
# PRODUCT_TYPE_ID
# 0                                                              0.0
# 2                                                              0.0
# 6                                                              0.0
# 227                                                            0.0
# 326                                                            0.0
# ...                                                            ...
# 12734                                                          0.0
# 12814                                                          0.0
# 12826                                                          0.0
# 12829                                                          0.0
# 13080                                                          0.0
#
# TITLE            1100 Series Aluminum Door Canopy with Support Arms  \
# PRODUCT_TYPE_ID
# 0                                                              0.0
# 2                                                              0.0
# 6                                                              0.0
# 227                                                            0.0
# 326                                                            0.0
# ...                                                            ...
# 12734                                                          0.0
# 12814                                                          0.0
# 12826                                                          0.0
# 12829                                                          0.0
# 13080                                                          0.0
#
# TITLE            17Hills® Camisole Tank Top Vest Racerback Sando Camis for Women, Girls (Pack of 2)  \
# PRODUCT_TYPE_ID
# 0                                                              0.0
# 2                                                              0.0
# 6                                                              0.0
# 227                                                            0.0
# 326                                                            0.0
# ...                                                            ...
# 12734                                                          0.0
# 12814                                                          0.0
# 12826                                                          0.0
# 12829                                                          0.0
# 13080                                                          0.0
#
# TITLE            2 Pcs Famous TIK Tok Leggings, Women Bubble Hip Butt Lifting Leggings Workout Tummy Control Yoga Tights  \
# PRODUCT_TYPE_ID
# 0                                                              0.0
# 2                                                              0.0
# 6                                                              0.0
# 227                                                            0.0
# 326                                                            0.0
# ...                                                            ...
# 12734                                                          0.0
# 12814                                                          0.0
# 12826                                                          0.0
# 12829                                                          0.0
# 13080                                                          0.0
#
# TITLE            2PCS Summer Clothes Outfit Sets, F_Gotal Baby Toddler Girls Floral Big Bowknot Sundress Print Sleeveless Dress + Hat Set  \
# PRODUCT_TYPE_ID
# 0                                                              0.0
# 2                                                              0.0
# 6                                                              0.0
# 227                                                            0.0
# 326                                                            0.0
# ...                                                            ...
# 12734                                                          0.0
# 12814                                                          0.0
# 12826                                                          0.0
# 12829                                                          0.0
# 13080                                                          0.0
#
# TITLE            34 Heritage Men's Charisma Relaxed Classic Denim  \
# PRODUCT_TYPE_ID
# 0                                                             0.0
# 2                                                             0.0
# 6                                                             0.0
# 227                                                           0.0
# 326                                                           0.0
# ...                                                           ...
# 12734                                                         0.0
# 12814                                                         0.0
# 12826                                                         0.0
# 12829                                                         0.0
# 13080                                                         0.0
#
# TITLE            3dRose Garden Flag, White  \
# PRODUCT_TYPE_ID
# 0                                      0.0
# 2                                      0.0
# 6                                      0.0
# 227                                    0.0
# 326                                    0.0
# ...                                    ...
# 12734                                  0.0
# 12814                                  0.0
# 12826                                  0.0
# 12829                                  0.0
# 13080                                  0.0
#
# TITLE            5 Ace Lion Sticker Poster|Animal Poster|wild life Poster|size:12x18 inch,multicolor  \
# PRODUCT_TYPE_ID
# 0                                                              0.0
# 2                                                              0.0
# 6                                                              0.0
# 227                                                            0.0
# 326                                                            0.0
# ...                                                            ...
# 12734                                                          0.0
# 12814                                                          0.0
# 12826                                                          0.0
# 12829                                                          0.0
# 13080                                                          0.0
#
# TITLE            ...  Zodiac womens Tracey Sandal Brown 8.5 M US  \
# PRODUCT_TYPE_ID  ...
# 0                ...                                         0.0
# 2                ...                                         0.0
# 6                ...                                         0.0
# 227              ...                                         0.0
# 326              ...                                         0.0
# ...              ...                                         ...
# 12734            ...                                         0.0
# 12814            ...                                         0.0
# 12826            ...                                         0.0
# 12829            ...                                         0.0
# 13080            ...                                         0.0
#
# TITLE            andy & natalie Women's Shiny Tops Holographic Metallic Shirt Shimmer Glitter Sparkle Party Disco Tee Shirt Blouse  \
# PRODUCT_TYPE_ID
# 0                                                              0.0
# 2                                                              0.0
# 6                                                              0.0
# 227                                                            0.0
# 326                                                            0.0
# ...                                                            ...
# 12734                                                          0.0
# 12814                                                          0.0
# 12826                                                          0.0
# 12829                                                          0.0
# 13080                                                          0.0
#
# TITLE            gsunmmw Gold Lace Flower Girl Dresses for Wedding Beaded Pageant Ball Gown First Communion Dress for Girls GS098  \
# PRODUCT_TYPE_ID
# 0                                                              0.0
# 2                                                              0.0
# 6                                                              0.0
# 227                                                            0.0
# 326                                                            0.0
# ...                                                            ...
# 12734                                                          0.0
# 12814                                                          0.0
# 12826                                                          0.0
# 12829                                                          0.0
# 13080                                                          0.0
#
# TITLE            iniber Women's Comfy Stretch Tie Dye Lounge Pants Wide Leg Casual Drawstring Pajamas with Laundry Bag  \
# PRODUCT_TYPE_ID
# 0                                                              0.0
# 2                                                              0.0
# 6                                                              0.0
# 227                                                            0.0
# 326                                                            0.0
# ...                                                            ...
# 12734                                                          0.0
# 12814                                                          0.0
# 12826                                                          0.0
# 12829                                                          0.0
# 13080                                                          0.0
#
# TITLE            kc (Kota Craetions) Kitchen Sticker Decorative Wall D�cor Oil Waterproof Wallpaper/Poster Colorful Multicolor Self Adhesive (PVC Vinyl)  \
# PRODUCT_TYPE_ID
# 0                                                              0.0
# 2                                                              0.0
# 6                                                              0.0
# 227                                                            0.0
# 326                                                            0.0
# ...                                                            ...
# 12734                                                          0.0
# 12814                                                          0.0
# 12826                                                          0.0
# 12829                                                          0.0
# 13080                                                          0.0
#
# TITLE            naioewe Onesie Pajamas for Women Sexy with Butt Flap Back Functional Long Sleeve Sleepwear Romper Jumpsuits Sleepwear  \
# PRODUCT_TYPE_ID
# 0                                                              0.0
# 2                                                              0.0
# 6                                                              0.0
# 227                                                            0.0
# 326                                                            0.0
# ...                                                            ...
# 12734                                                          0.0
# 12814                                                          0.0
# 12826                                                          0.0
# 12829                                                          0.0
# 13080                                                          0.0
#
# TITLE            shoe craft women and girls casual wedges slippers size UK (3)  \
# PRODUCT_TYPE_ID
# 0                                                              0.0
# 2                                                              0.0
# 6                                                              0.0
# 227                                                            0.0
# 326                                                            0.0
# ...                                                            ...
# 12734                                                          0.0
# 12814                                                          0.0
# 12826                                                          0.0
# 12829                                                          0.0
# 13080                                                          0.0
#
# TITLE            zia carpets Carved Embossed Carpet for Your Home with 1 inch Thickness 6 x 8 Feet  \
# PRODUCT_TYPE_ID
# 0                                                              0.0
# 2                                                              0.0
# 6                                                              0.0
# 227                                                            0.0
# 326                                                            0.0
# ...                                                            ...
# 12734                                                          0.0
# 12814                                                          0.0
# 12826                                                          0.0
# 12829                                                          0.0
# 13080                                                          0.0
#
# TITLE            zia carpets Handmade Woollen Thick Modern Tuffted Carpet (Export Quality) for Drawing Room Carpets Size 4 x 6 feet  \
# PRODUCT_TYPE_ID
# 0                                                              0.0
# 2                                                              0.0
# 6                                                              0.0
# 227                                                            0.0
# 326                                                            0.0
# ...                                                            ...
# 12734                                                          0.0
# 12814                                                          0.0
# 12826                                                          0.0
# 12829                                                          0.0
# 13080                                                          0.0
#
# TITLE            zia carpets Modern Soft Shaggy Rugs Fluffy Home Decorative Carpet for Living Room 2-inch Thick Carpet 5 X 7 Feet
# PRODUCT_TYPE_ID
# 0                                                              0.0
# 2                                                              0.0
# 6                                                              0.0
# 227                                                            0.0
# 326                                                            0.0
# ...                                                            ...
# 12734                                                          0.0
# 12814                                                          0.0
# 12826                                                          0.0
# 12829                                                          0.0
# 13080                                                          0.0
#
# [239 rows x 885 columns]

# %%
similarity_scores_user = cosine_similarity(pt_user_based)

# %%
def recommend_user_based(user):
    # index fetch for the user
    index = np.where(pt_user_based.index == user)[0][0]
    # Finding similar users
    similar_users = sorted(list(enumerate(similarity_scores_user[index])), key=lambda x: x[1], reverse=True)[1:3]
    
    # Assuming you want to recommend items, you need to look at these users' interactions
    recommended_items = set()
    for i, _ in similar_users:
        # Fetch top N items for each similar user
        user_items = pt_user_based.columns[np.where(pt_user_based.iloc[i] > 0)].tolist()
        recommended_items.update(user_items)
    
    # Optionally, filter out items the user has already interacted with
    current_user_items = set(pt_user_based.columns[np.where(pt_user_based.iloc[index] > 0)])
    recommended_items.difference_update(current_user_items)
    
    return list(recommended_items)[:5]

# %%
recommended_items = recommend_user_based(326)
print(recommended_items)
# Out:
# ['Design Cart Designer Printed Hard Case Back Cover for Vivo Y83 Pro/Vivo 1726', 'ASICS Gel-Contend 5 Men&#39;s Running Shoes', 'Namaste Home 14 inch Laptop Skin - Beautiful - Laptop Sticker - HD Quality (Eco Matte Vinyl, 14 inch, Multicolor)', 'ASICS Men&#39;s Gel-Nimbus 22 Running Shoes', 'BOGATCHI Chocolate Gift Box, Happy Diwali Chocolate, Diwali Chocolate Gifts, Diwali Chocolate Gift, Diwali Chocolate BAR, Diwali Gifts, 15 Pieces']
